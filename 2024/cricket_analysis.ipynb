# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('IPL_IMB_data.csv')

# %%
df.head()
# Out:
#     PLAYER NAME  AGE COUNTRY PLAYING ROLE  T-RUNS  T-WKTS  ODI-RUNS-S  \
# 0   Abdulla, YA    2      SA   Allrounder       0       0           0
# 1  Abdur Razzak    2     BAN       Bowler     214      18         657
# 2   Agarkar, AB    2     IND       Bowler     571      58        1269
# 3     Ashwin, R    1     IND       Bowler     284      31         241
# 4  Badrinath, S    2     IND      Batsman      63       0          79
#
#    ODI-SR-B  ODI-WKTS  ODI-SR-BL  ...  HS    AVE    SR-B  SIXERS  RUNS-C  \
# 0      0.00         0        0.0  ...   0   0.00    0.00       0     307
# 1     71.41       185       37.6  ...   0   0.00    0.00       0      29
# 2     80.62       288       32.9  ...  39  18.56  121.01       5    1059
# 3     84.56        51       36.8  ...  11   5.80   76.32       0    1125
# 4     45.93         0        0.0  ...  71  32.93  120.71      28       0
#
#    WKTS  AVE-BL   ECON  SR-BL  SOLD PRICE
# 0    15   20.47   8.90  13.93       50000
# 1     0    0.00  14.50   0.00       50000
# 2    29   36.52   8.81  24.90      350000
# 3    49   22.96   6.23  22.14      850000
# 4     0    0.00   0.00   0.00      800000
#
# [5 rows x 22 columns]

# %%
df.dtypes
# Out:
# PLAYER NAME       object
# AGE                int64
# COUNTRY           object
# PLAYING ROLE      object
# T-RUNS             int64
# T-WKTS             int64
# ODI-RUNS-S         int64
# ODI-SR-B         float64
# ODI-WKTS           int64
# ODI-SR-BL        float64
# CAPTAINCY EXP      int64
# RUNS-S             int64
# HS                 int64
# AVE              float64
# SR-B             float64
# SIXERS             int64
# RUNS-C             int64
# WKTS               int64
# AVE-BL           float64
# ECON             float64
# SR-BL            float64
# SOLD PRICE         int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# PLAYER NAME      0
# AGE              0
# COUNTRY          0
# PLAYING ROLE     0
# T-RUNS           0
# T-WKTS           0
# ODI-RUNS-S       0
# ODI-SR-B         0
# ODI-WKTS         0
# ODI-SR-BL        0
# CAPTAINCY EXP    0
# RUNS-S           0
# HS               0
# AVE              0
# SR-B             0
# SIXERS           0
# RUNS-C           0
# WKTS             0
# AVE-BL           0
# ECON             0
# SR-BL            0
# SOLD PRICE       0
# dtype: int64

# %%
df.describe()
# Out:
#               AGE        T-RUNS      T-WKTS    ODI-RUNS-S    ODI-SR-B  \
# count  130.000000    130.000000  130.000000    130.000000  130.000000
# mean     2.092308   2166.715385   66.530769   2508.738462   71.164385
# std      0.576627   3305.646757  142.676855   3582.205625   25.898440
# min      1.000000      0.000000    0.000000      0.000000    0.000000
# 25%      2.000000     25.500000    0.000000     73.250000   65.650000
# 50%      2.000000    542.500000    7.000000    835.000000   78.225000
# 75%      2.000000   3002.250000   47.500000   3523.500000   86.790000
# max      3.000000  15470.000000  800.000000  18426.000000  116.660000
#
#          ODI-WKTS   ODI-SR-BL  CAPTAINCY EXP       RUNS-S          HS  \
# count  130.000000  130.000000     130.000000   130.000000  130.000000
# mean    76.076923   34.033846       0.315385   514.246154   47.430769
# std    111.205070   26.751749       0.466466   615.226335   36.403624
# min      0.000000    0.000000       0.000000     0.000000    0.000000
# 25%      0.000000    0.000000       0.000000    39.000000   16.000000
# 50%     18.500000   36.600000       0.000000   172.000000   35.500000
# 75%    106.000000   45.325000       1.000000   925.250000   73.750000
# max    534.000000  150.000000       1.000000  2254.000000  158.000000
#
#               AVE        SR-B      SIXERS       RUNS-C        WKTS  \
# count  130.000000  130.000000  130.000000   130.000000  130.000000
# mean    18.719308  111.053462   17.692308   475.523077   17.169231
# std     11.094224   35.928907   23.828146   558.314049   21.816763
# min      0.000000    0.000000    0.000000     0.000000    0.000000
# 25%      9.825000   98.237500    1.000000     0.000000    0.000000
# 50%     18.635000  118.510000    6.000000   297.000000    8.500000
# 75%     27.872500  129.102500   29.750000   689.250000   23.750000
# max     50.110000  235.490000  129.000000  1975.000000   83.000000
#
#            AVE-BL        ECON       SR-BL    SOLD PRICE
# count  130.000000  130.000000  130.000000  1.300000e+02
# mean    23.110231    6.204462   17.382615  5.212231e+05
# std     20.802057    4.941531   15.273422  4.068074e+05
# min      0.000000    0.000000    0.000000  2.000000e+04
# 25%      0.000000    0.000000    0.000000  2.250000e+05
# 50%     24.785000    7.380000   19.935000  4.375000e+05
# 75%     35.580000    8.247500   26.212500  7.000000e+05
# max    126.300000   38.110000  100.200000  1.800000e+06

# %%
plt.figure(figsize=(15,8))
df.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# # shortcut to do the eda using pandas profiling

# %%
pip install pydantic_settings
# Out:
# Collecting pydantic_settings
#   Downloading pydantic_settings-2.2.1-py3-none-any.whl.metadata (3.1 kB)
# Collecting pydantic>=2.3.0 (from pydantic_settings)
#   Using cached pydantic-2.6.4-py3-none-any.whl.metadata (85 kB)
# Collecting python-dotenv>=0.21.0 (from pydantic_settings)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\hemant\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=2.3.0->pydantic_settings) (0.6.0)
# Requirement already satisfied: pydantic-core==2.16.3 in c:\users\hemant\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=2.3.0->pydantic_settings) (2.16.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\hemant\appdata\local\programs\python\python311\lib\site-packages (from pydantic>=2.3.0->pydantic_settings) (4.10.0)
# Downloading pydantic_settings-2.2.1-py3-none-any.whl (13 kB)
# Using cached pydantic-2.6.4-py3-none-any.whl (394 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv, pydantic, pydantic_settings
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.0
#     Uninstalling pydantic-1.0:
#       Successfully uninstalled pydantic-1.0
# Successfully installed pydantic-2.6.4 pydantic_settings-2.2.1 python-dotenv-1.0.1
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires visions[type_image_path]==0.7.4, but you have visions 0.7.6 which is incompatible.

# %%
# from pydantic_settings import BaseSettings

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from pandas_profiling import ProfileReport
profile=ProfileReport(df)
profile.to_file(output_file='cricketEDA.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
